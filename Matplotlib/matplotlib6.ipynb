# %% [markdown]
# Histograms, Binnings, and Density

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use("ggplot")

# %%
data = np.random.rand(100)

# %%
plt.hist(data)
plt.show()

# %%
plt.hist(data, bins = 30, alpha = 0.5,
         histtype="stepfilled", color = "steelblue",
         edgecolor = "none")
plt.show()

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, bins=40)
plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs)
# Out:
# (array([ 3.,  0.,  6.,  6.,  5., 10.,  8., 21., 15., 22., 18., 29., 40.,
#         36., 55., 54., 60., 46., 57., 60., 60., 57., 49., 47., 48., 43.,
#         32., 24., 21., 20., 17., 12.,  6.,  4.,  4.,  1.,  1.,  1.,  0.,
#          2.]),
#  array([-2.47829191, -2.18659056, -1.89488921, -1.60318786, -1.3114865 ,
#         -1.01978515, -0.7280838 , -0.43638245, -0.1446811 ,  0.14702025,
#          0.4387216 ,  0.73042295,  1.0221243 ,  1.31382565,  1.605527  ,
#          1.89722835,  2.1889297 ,  2.48063105,  2.7723324 ,  3.06403375,
#          3.3557351 ,  3.64743645,  3.9391378 ,  4.23083915,  4.5225405 ,
#          4.81424185,  5.1059432 ,  5.39764455,  5.6893459 ,  5.98104725,
#          6.2727486 ,  6.56444995,  6.8561513 ,  7.14785265,  7.439554  ,
#          7.73125535,  8.0229567 ,  8.31465805,  8.6063594 ,  8.89806075,
#          9.1897621 ]),
#  [<matplotlib.patches.Polygon at 0x1f855c60410>])

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [21 14 25 20 20]

# %%
df = pd.read_csv("car_prices.csv")
df.head()
# Out:
#    id    brand          model  model_year  milage fuel_type  \
# 0   0     Ford   F-150 Lariat        2018   74349  Gasoline
# 1   1      BMW          335 i        2007   80000  Gasoline
# 2   2   Jaguar      XF Luxury        2009   91491  Gasoline
# 3   3      BMW   X7 xDrive40i        2022    2437    Hybrid
# 4   4  Pontiac  Firebird Base        2001  111000  Gasoline
#
#                                               engine  \
# 0      375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3  335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 4      200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col       accident clean_title  \
# 0                    10-Speed A/T    Blue    Gray  None reported         Yes
# 1                     6-Speed M/T   Black   Black  None reported         Yes
# ...

# %%
df.isna().sum()
# Out:
# id              0
# brand           0
# model           0
# model_year      0
# milage          0
# fuel_type       0
# engine          0
# transmission    0
# ext_col         0
# int_col         0
# accident        0
# clean_title     0
# price           0
# dtype: int64

# %%
df.groupby("brand")["price"].agg(
    mean_price = "mean",
    min_pirce = "min",
    max_price = "max",
    count = "count"
)
# Out:
#                  mean_price  min_pirce  max_price  count
# brand
# Acura          2.789955e+04       2500    2954083    580
# Alfa           4.571224e+04       6399     399950    144
# Aston          1.178858e+05       5500     489995     50
# Audi           3.709137e+04       2000    2954083   2922
# BMW            4.027603e+04       2300     749950   7369
# Bentley        1.052118e+05       2899     749950    284
# Bugatti        1.950995e+06    1950995    1950995      1
# Buick          2.769325e+04       2800     274900    228
# Cadillac       3.657584e+04       2800     695000   1565
# Chevrolet      4.475111e+04       2000    2954083   4424
# Chrysler       1.951867e+04       2500     749950    258
# Dodge          2.893806e+04       2500     695000   1011
# FIAT           1.418388e+04       8500      20000     16
# Ferrari        1.584043e+05      10500     599000     87
# Ford           3.815406e+04       2000     749950   6706
# ...

# %%
mean_price = df.groupby("brand")["price"].mean()

plt.hist(mean_price)
plt.show()

# %%
df
# Out:
#           id    brand                             model  model_year  milage  \
# 0          0     Ford                      F-150 Lariat        2018   74349
# 1          1      BMW                             335 i        2007   80000
# 2          2   Jaguar                         XF Luxury        2009   91491
# 3          3      BMW                      X7 xDrive40i        2022    2437
# 4          4  Pontiac                     Firebird Base        2001  111000
# ...      ...      ...                               ...         ...     ...
# 54268  54268      BMW                      X6 xDrive50i        2017   29000
# 54269  54269     Audi                   A4 2.0T Premium        2015   94634
# 54270  54270  Porsche                         Cayenne S        2013   40989
# 54271  54271  Porsche                 911 Carrera 4 GTS        2023    1518
# 54272  54272     Audi  A5 Sportback S line Premium Plus        2021   35000
#
# ...

# %%
data1 = df.pivot_table(columns= "fuel_type", index= "brand", aggfunc= "size", fill_value= 0)
data1
# Out:
# fuel_type      Diesel  E85 Flex Fuel  Gasoline  Hybrid  Plug-In Hybrid  \
# brand
# Acura               0              3       568       4               0
# Alfa                0              0       144       0               0
# Aston               0              0        50       0               0
# Audi               38            117      2434     331               1
# BMW                 2              2      6972     324              68
# Bentley             0              5       278       0               0
# Bugatti             0              0         1       0               0
# Buick               0              7       220       1               0
# Cadillac           16            104      1432       0               0
# Chevrolet          58            301      4032       4               0
# Chrysler            0             37       210       1               0
# Dodge              19             23       910       0               0
# ...

# %%
plt.figure(figsize=(15, 10))
plt.hist(data1)
plt.legend("fuel_type")
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(data1)
plt.xticks(rotation = 90)
plt.legend("fuel_type")
plt.show()

# %%
"""                        Two-Dimensional Histograms and Binnings                           """
# Out:
# '                        Two-Dimensional Histograms and Binnings                           '

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %%
counts, xedges, yedges = np.histogram2d(x, y, bins=30)

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')

# %%
from scipy.stats import gaussian_kde

# [Ndim, Nsamples] o‘lchamli massiv
data = np.vstack([x, y])
kde = gaussian_kde(data)

# muntazam grid’da baholash
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)

Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

# Natijani tasvir sifatida chizish
plt.imshow(
    Z.reshape(Xgrid.shape),
    origin='lower',
    aspect='auto',
    extent=[-3.5, 3.5, -6, 6],
    cmap='Blues'
)

cb = plt.colorbar()
cb.set_label("density")

# %%
df.head()
# Out:
#    id    brand          model  model_year  milage fuel_type  \
# 0   0     Ford   F-150 Lariat        2018   74349  Gasoline
# 1   1      BMW          335 i        2007   80000  Gasoline
# 2   2   Jaguar      XF Luxury        2009   91491  Gasoline
# 3   3      BMW   X7 xDrive40i        2022    2437    Hybrid
# 4   4  Pontiac  Firebird Base        2001  111000  Gasoline
#
#                                               engine  \
# 0      375.0HP 3.5L V6 Cylinder Engine Gasoline Fuel
# 1  300.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 2       300.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3  335.0HP 3.0L Straight 6 Cylinder Engine Gasoli...
# 4      200.0HP 3.8L V6 Cylinder Engine Gasoline Fuel
#
#                      transmission ext_col int_col       accident clean_title  \
# 0                    10-Speed A/T    Blue    Gray  None reported         Yes
# 1                     6-Speed M/T   Black   Black  None reported         Yes
# ...

# %%
data2 = df.groupby(["brand"])["price"].mean()
data3 = df.groupby(["brand"])["fuel_type"].sum()

# %%
plt.figure(figsize= (12, 6))
plt.hist(data2, bins= 53)
plt.show()

# %%
plt.figure(figsize= (12, 6))
plt.plot(data2)
plt.xticks(rotation = 90)
plt.show()
