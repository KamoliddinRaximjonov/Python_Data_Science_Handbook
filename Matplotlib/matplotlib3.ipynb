# %% [markdown]
# Simple Scatter Plots

# %%
"""                                 Scatter Plots with plt.plot                             """
# Out:
# '                                 Scatter Plots with plt.plot                             '

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.style.use("ggplot")

# %%
x= np.linspace(0, 10, 30)
y= np.sin(x)
plt.plot(x, y, "o", color= "black")
plt.show()

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker, 
             label = "marker= '{0}' ".format(marker))
    
plt.legend(numpoints= 1)
plt.xlim(0, 1.8)
# Out:
# (0.0, 1.8)

# %%
plt.plot(x, y, "-ok")   # chiziq (-), doira marker (o), qora rang (k)
plt.show()

# %%
plt.plot(x, y, '-p', color='gray',
         markersize=15, linewidth=4,
         markerfacecolor='white',
         markeredgecolor='gray',
         markeredgewidth=2)

plt.ylim(-1.2, 1.2);

# %%
"""                            Scatter Plots with plt.scatter                               """
# Out:
# '                            Scatter Plots with plt.scatter                               '

# %%
plt.scatter(x, y, marker= "o")

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # rang shkalasini ko‘rsatish

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[0], features[1], alpha=0.2,
            s=100 * features[3], c=iris.target,
            cmap='viridis')

plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
t = np.linspace(0, 2*np.pi, 2000)

scale = 2.5

x = scale * 16 * np.sin(t)**3
y = scale * (13*np.cos(t) - 5*np.cos(2*t)
             - 2*np.cos(3*t) - np.cos(4*t))

plt.figure(figsize=(8, 8))
plt.plot(x, y, color='red', linewidth=3)
plt.gca().set_aspect('equal')
plt.title("Yurakcha")
plt.show()

# %%
t = np.linspace(0, 2*np.pi, 2000)
scale = 2.5

x = scale * 16 * np.sin(t)**3
y = scale * (13*np.cos(t) - 5*np.cos(2*t)
             - 2*np.cos(3*t) - np.cos(4*t))

plt.figure(figsize=(8, 8))
plt.plot(x, y, color='red', linewidth=3)

# Ism yozish
plt.text(0, -10, "Fotima",
         fontsize=40,
         color='darkred',
         ha='center',
         fontweight='bold')

plt.gca().set_aspect('equal')
plt.axis('off')
plt.show()
